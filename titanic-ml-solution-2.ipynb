# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Opening Datasets
train = pd.read_csv("data/train.csv")
test = pd.read_csv("data/test.csv")

train.set_index(["PassengerId"], inplace=True)
train.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Parte 1: Selección de Características
#
# En esta sección se eligen las características que se utilizarán para trabajar el modelo, se transformarán y se crearán otras nuevas de cara a la ejecución y prueba del modelo.
#
# ### 1.1. Name

# %%
train_test_data = [train, test]
for df in train_test_data:
    df["title"] = df["Name"].str.extract(" ([A-Za-z]+)\.", expand=False)

# %%
train["title"].value_counts()
# Out:
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Col           2
# Major         2
# Ms            1
# Jonkheer      1
# Countess      1
# Don           1
# Mme           1
# Lady          1
# Sir           1
# Capt          1
# Name: title, dtype: int64

# %%
title_mapping = {"Mlle": "high", "Ms": "high", "Mme": "high", 
                 "Sir": "high", "Lady": "high", "Countess": "high", 
                 "Mrs": "high", "Miss": "high", "Master": "mid", 
                 "Major": "mid", "Col": "mid", "Dr": "mid", 
                 "Mr": "low", "Rev": "low", "Dona": "low", 
                 "Jonkheer": "low", "Don": "low", "Capt": "low" }

for dataset in train_test_data:
    dataset["title"] = dataset["title"].map(title_mapping)

# %%
train.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked title
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   low
# 2                1      0          PC 17599  71.2833   C85        C  high
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  high
# 4                1      0            113803  53.1000  C123        S  high
# 5                0      0            373450   8.0500   NaN        S   low

# %% [markdown]
# ### 1.2. Pclass

# %%
pclass_mapping = {1: "high", 2: "mid", 3: "low"}

for dataset in train_test_data:
    dataset["class"] = dataset["Pclass"].map(pclass_mapping)

# %%
train.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked title  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   low
# 2                1      0          PC 17599  71.2833   C85        C  high
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  high
# 4                1      0            113803  53.1000  C123        S  high
# 5                0      0            373450   8.0500   NaN        S   low
#
#             class
# PassengerId
# 1             low
# 2            high
# 3             low
# 4            high
# 5             low

# %% [markdown]
# ### 1.3. Sex

# %%
sex_mapping = { 'male': 0, 'female': 1 }
for dataset in train_test_data:
    dataset['sex'] = dataset['Sex'].map(sex_mapping)

# %%
train.head(5)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked title  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   low
# 2                1      0          PC 17599  71.2833   C85        C  high
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  high
# 4                1      0            113803  53.1000  C123        S  high
# 5                0      0            373450   8.0500   NaN        S   low
#
#             class  sex
# PassengerId
# 1             low    0
# 2            high    1
# 3             low    1
# 4            high    1
# 5             low    0

# %% [markdown]
# ### 1.4. Age

# %%
train["Age"].fillna(train.groupby("title")["Age"].transform("median"), inplace=True)
test["Age"].fillna(test.groupby("title")["Age"].transform("median"), inplace=True)

dataset = [train, test]

for dataset in train_test_data:
    dataset.loc[dataset["Age"] <= 5, "age"] = "little_infant"
    dataset.loc[(dataset["Age"] > 5) & (dataset["Age"] <= 11), "age"] = "infant"
    dataset.loc[(dataset["Age"] > 12) & (dataset["Age"] <= 18), "age"] = "teen"
    dataset.loc[(dataset["Age"] > 18) & (dataset["Age"] <= 25), "age"] = "young"
    dataset.loc[(dataset["Age"] > 25) & (dataset["Age"] <= 60), "age"] = "adult"
    dataset.loc[ dataset["Age"] > 60, "age"] = "old"

train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked title  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   low
# 2                1      0          PC 17599  71.2833   C85        C  high
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  high
# 4                1      0            113803  53.1000  C123        S  high
# 5                0      0            373450   8.0500   NaN        S   low
#
#             class  sex    age
# PassengerId
# 1             low    0  young
# 2            high    1  adult
# 3             low    1  adult
# 4            high    1  adult
# 5             low    0  adult

# %% [markdown]
# ### 1.5. SibSp & Parch

# %%
for dataset in train_test_data:
    dataset["family_tmp"] = dataset["SibSp"]+dataset["Parch"]+1
    dataset.loc[dataset["family_tmp"] <= 1, "family_size"] = "alone",
    dataset.loc[(dataset["family_tmp"] > 1) & (dataset["family_tmp"] <= 3), "family_size"] = "small",
    dataset.loc[(dataset["family_tmp"] > 3) & (dataset["family_tmp"] <= 6), "family_size"] = "mid",
    dataset.loc[ dataset["family_tmp"] > 6, "family_size"] = "giant"

train = train.drop(['family_tmp'], axis=1)
test = test.drop(['family_tmp'], axis=1)

train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked title  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   low
# 2                1      0          PC 17599  71.2833   C85        C  high
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  high
# 4                1      0            113803  53.1000  C123        S  high
# 5                0      0            373450   8.0500   NaN        S   low
#
#             class  sex    age family_size
# PassengerId
# 1             low    0  young       small
# 2            high    1  adult       small
# 3             low    1  adult       alone
# 4            high    1  adult       small
# 5             low    0  adult       alone

# %% [markdown]
# ### 1.6. Ticket

# %%
train = train.drop(["Ticket"], axis=1)
test = test.drop(["Ticket"], axis=1)
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch     Fare Cabin Embarked title class  sex    age  \
# PassengerId
# 1                1      0   7.2500   NaN        S   low   low    0  young
# 2                1      0  71.2833   C85        C  high  high    1  adult
# 3                0      0   7.9250   NaN        S  high   low    1  adult
# 4                1      0  53.1000  C123        S  high  high    1  adult
# 5                0      0   8.0500   NaN        S   low   low    0  adult
#
#             family_size
# PassengerId
# 1                 small
# 2                 small
# 3                 alone
# 4                 small
# 5                 alone

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Cabin Embarked title class  sex    age  \
# 0  34.5      0      0   7.8292   NaN        Q   low   low    0  adult
# 1  47.0      1      0   7.0000   NaN        S  high   low    1  adult
# 2  62.0      0      0   9.6875   NaN        Q   low   mid    0    old
# 3  27.0      0      0   8.6625   NaN        S   low   low    0  adult
# 4  22.0      1      1  12.2875   NaN        S  high   low    1  young
#
#   family_size
# 0       alone
# 1       small
# 2       alone
# 3       alone
# 4       small

# %% [markdown]
# ### 1.7. Fare

# %%
train["Fare"].fillna(train["Fare"].median(), inplace=True)
train.loc[train["Fare"] <= 8.0, "fare"] = "low"
train.loc[(train["Fare"] > 8.0) & (train["Fare"] <= 15.0), "fare"] = "mid"
train.loc[(train["Fare"] > 15.0) & (train["Fare"] <= 31.0), "fare"] = "high"
train.loc[train["Fare"] > 31.0, "fare"] = "highest"
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch     Fare Cabin Embarked title class  sex    age  \
# PassengerId
# 1                1      0   7.2500   NaN        S   low   low    0  young
# 2                1      0  71.2833   C85        C  high  high    1  adult
# 3                0      0   7.9250   NaN        S  high   low    1  adult
# 4                1      0  53.1000  C123        S  high  high    1  adult
# 5                0      0   8.0500   NaN        S   low   low    0  adult
#
#             family_size     fare
# PassengerId
# 1                 small      low
# 2                 small  highest
# 3                 alone      low
# 4                 small  highest
# 5                 alone      mid

# %%
test["Fare"].fillna(test["Fare"].median(), inplace=True)
test.loc[test["Fare"] <= 8.0, "fare"] = "low"
test.loc[(test["Fare"] > 8.0) & (test["Fare"] <= 15.0), "fare"] = "mid"
test.loc[(test["Fare"] > 15.0) & (test["Fare"] <= 31.0), "fare"] = "high"
test.loc[test["Fare"] > 31.0, "fare"] = "highest"
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Cabin Embarked title class  sex    age  \
# 0  34.5      0      0   7.8292   NaN        Q   low   low    0  adult
# 1  47.0      1      0   7.0000   NaN        S  high   low    1  adult
# 2  62.0      0      0   9.6875   NaN        Q   low   mid    0    old
# 3  27.0      0      0   8.6625   NaN        S   low   low    0  adult
# 4  22.0      1      1  12.2875   NaN        S  high   low    1  young
#
#   family_size fare
# 0       alone  low
# 1       small  low
# 2       alone  mid
# 3       alone  mid
# 4       small  mid

# %% [markdown]
# ### 1.8. Cabin

# %%
drop = ['Cabin']
train.drop(drop, axis=1,inplace=True)
test.drop(drop, axis=1, inplace=True)

train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch     Fare Embarked title class  sex    age  \
# PassengerId
# 1                1      0   7.2500        S   low   low    0  young
# 2                1      0  71.2833        C  high  high    1  adult
# 3                0      0   7.9250        S  high   low    1  adult
# 4                1      0  53.1000        S  high  high    1  adult
# 5                0      0   8.0500        S   low   low    0  adult
#
#             family_size     fare
# PassengerId
# 1                 small      low
# 2                 small  highest
# 3                 alone      low
# 4                 small  highest
# 5                 alone      mid

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Embarked title class  sex    age family_size  \
# 0  34.5      0      0   7.8292        Q   low   low    0  adult       alone
# 1  47.0      1      0   7.0000        S  high   low    1  adult       small
# 2  62.0      0      0   9.6875        Q   low   mid    0    old       alone
# 3  27.0      0      0   8.6625        S   low   low    0  adult       alone
# 4  22.0      1      1  12.2875        S  high   low    1  young       small
#
#   fare
# 0  low
# 1  low
# 2  mid
# 3  mid
# 4  mid

# %% [markdown]
# ### 1.9. Embarked

# %%
train['embarked'] = train['Embarked']
test['embarked'] = test['Embarked']
train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch     Fare Embarked title class  sex    age  \
# PassengerId
# 1                1      0   7.2500        S   low   low    0  young
# 2                1      0  71.2833        C  high  high    1  adult
# 3                0      0   7.9250        S  high   low    1  adult
# 4                1      0  53.1000        S  high  high    1  adult
# 5                0      0   8.0500        S   low   low    0  adult
#
#             family_size     fare embarked
# PassengerId
# 1                 small      low        S
# 2                 small  highest        C
# 3                 alone      low        S
# 4                 small  highest        S
# 5                 alone      mid        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch     Fare Embarked title class  sex    age family_size  \
# 0  34.5      0      0   7.8292        Q   low   low    0  adult       alone
# 1  47.0      1      0   7.0000        S  high   low    1  adult       small
# 2  62.0      0      0   9.6875        Q   low   mid    0    old       alone
# 3  27.0      0      0   8.6625        S   low   low    0  adult       alone
# 4  22.0      1      1  12.2875        S  high   low    1  young       small
#
#   fare embarked
# 0  low        Q
# 1  low        S
# 2  mid        Q
# 3  mid        S
# 4  mid        S
